# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rfdetr/pareto.png)
#
# The RF-DETR family of models stands as the quickest and most precise in object detection across all sizes. RF-DETR has achieved over 60 mAP on the Microsoft COCO benchmark, a leading measure of object detection performance. It also sets new records on RF100-VL, a benchmark that shows how well models adapt to real-world problems beyond standard datasets.
#
# The RF-DETR model group includes five sizes: Nano, Small, Medium, Base, and Large. These models offer a range of options for different needs. For example, RF-DETR-Nano is 11 mAP higher than YOLO11-n (on mAP50:95) and runs 0.17 ms faster. Likewise, RF-DETR-Small is 1.8 mAP better than YOLO11-x (the biggest YOLO11 model) and speeds things up by a good 7.77 ms. This wide range of models makes RF-DETR a great choice for many real-world uses, from small devices that need to be super fast to bigger jobs that demand top precision.
#
# RF-DETR is small enough to run on edge devices, making it perfect for deployments that need both high accuracy and real-time performance. You can easily get started with any of the RF-DETR models, as they're ready for training in the cloud with Roboflow or through the free RF-DETR Python package.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Mon Nov  3 23:28:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   55C    P5             N/A /  115W |     976MiB /   8188MiB |     11%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1292    C+G   ...on\wallpaper_engine\wallpaper32.exe      N/A      |
# |    0   N/A  N/A      1932    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A      2812    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A      5400    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A      5684    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A      6816    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A      7156    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A      9872    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     10012    C+G   ...cw5n1h2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A     10644    C+G   ...10.0_x64__zpdnekdrzrea0\Spotify.exe      N/A      |
# |    0   N/A  N/A     10828    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13448    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     13648    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     14000    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A     14704    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     16740    C+G   ...n\NVIDIA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A     16956    C+G   ...on\141.0.3537.99\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     17636    C+G   C:\Program Files\cursor\Cursor.exe          N/A      |
# |    0   N/A  N/A     17812    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     22620    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Download example data
#
# Downloads example images for testing. You can use these or replace them with your own images.

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model
#
# Runs inference on an example image using a pretrained RF-DETR Medium model (trained on COCO). To use a different model size, simply replace `RFDETRMedium` with `RFDETRNano`, `RFDETRSmall`, `RFDETRBase` or `RFDETRLarge` as needed.

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("dog-2.jpeg")

model = RFDETRMedium(resolution=640)
model.optimize_for_inference()

detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\Context.cpp:85.)
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4319.)
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# <PIL.Image.Image image mode=RGB size=450x800>

# %%
import cv2
import supervision as sv
from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES
from PIL import Image

# --- Configuration ---
SOURCE_VIDEO_PATH = "vehicle-counting.mp4"
TARGET_VIDEO_PATH = "output_video.mp4"
CONFIDENCE_THRESHOLD = 0.5
# ---------------------

print("Loading RF-DETR Medium model (pre-trained on COCO)...")
# Load the pre-trained RF-DETR Medium model
model = RFDETRMedium(weights="coco")
# Optimize the model for faster inference
model.optimize_for_inference()
print("Model loaded successfully.")

# Initialize supervision annotators
box_annotator = sv.BoxAnnotator(
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    text_position=sv.Position.TOP_CENTER,
    text_scale=0.5,
    text_thickness=1,
)

print(f"Opening video file: {SOURCE_VIDEO_PATH}")
# Open the source video file
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# Get video properties (width, height, fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create a video writer to save the output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
writer = cv2.VideoWriter(TARGET_VIDEO_PATH, fourcc, fps, (width, height))

print(f"Processing video and saving to: {TARGET_VIDEO_PATH}")
frame_count = 0
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    if not success:
        # End of video
        break

    # 1. Convert frame for model
    # OpenCV uses BGR, but RF-DETR (like most models) expects RGB.
    # We also convert it to a PIL Image, which the .predict() method expects.
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_image = Image.fromarray(rgb_frame)

    # 2. Run Inference
    # The .predict() method returns a supervision.Detections object
    detections = model.predict(pil_image, threshold=CONFIDENCE_THRESHOLD)
    
    # 3. Create labels
    labels = [
        f"{COCO_CLASSES[class_id]} {confidence:.2f}"
        for class_id, confidence 
        in zip(detections.class_id, detections.confidence)
    ]

    # 4. Annotate the original frame (BGR)
    annotated_frame = box_annotator.annotate(
        scene=frame.copy(), 
        detections=detections
    )
    annotated_frame = label_annotator.annotate(
        scene=annotated_frame, 
        detections=detections, 
        labels=labels
    )

    # 5. Write the annotated frame to the output video
    writer.write(annotated_frame)
    
    frame_count += 1
    if frame_count % 30 == 0: # Print progress every 30 frames
        print(f"Processed {frame_count} frames...")

    # (Optional) Display the output in a window
    # cv2.imshow("RF-DETR Inference", annotated_frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #    break

# --- Cleanup ---
cap.release()
writer.release()
cv2.destroyAllWindows()
print(f"Done! Processed {frame_count} frames. Output saved to {TARGET_VIDEO_PATH}")
# Out:
# Loading RF-DETR Medium model (pre-trained on COCO)...
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# Model loaded successfully.
# Opening video file: vehicle-counting.mp4
# Processing video and saving to: output_video.mp4
# Processed 30 frames...
# Processed 60 frames...
# Processed 90 frames...
# Processed 120 frames...
# Processed 150 frames...
# Processed 180 frames...
# Processed 210 frames...
# Processed 240 frames...
# Processed 270 frames...
# Processed 300 frames...
# Processed 330 frames...
# Processed 360 frames...
# Processed 390 frames...
# Processed 420 frames...
# Processed 450 frames...
# Processed 480 frames...
# Processed 510 frames...
# Done! Processed 538 frames. Output saved to output_video.mp4

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sjKAVuO8Lkaq5h2dDfDA")
project = rf.workspace("fyp-vfrgn").project("vehicle-body-style-dataset-gdxhw")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.cuda.device_count())
# Out:
# True
# 12.6
# 1

# %%
# from rfdetr import RFDETRMedium

# model = RFDETRMedium()

# model.train(dataset_dir=dataset.location, epochs=10, batch_size=4, grad_accum_steps=4)
from rfdetr import RFDETRBase

model = RFDETRBase()
history = []

def callback2(data):
	history.append(data)

model.callbacks["on_fit_epoch_end"].append(callback2)

model.train(dataset_dir=dataset.location, epochs=15, batch_size=4, grad_accum_steps=4, lr=1e-4)
# Out:
# Loading pretrain weights
# num_classes mismatch: model has 90 classes, but your dataset has 13 classes
# reinitializing your detection head with 13 classes.
# Unable to initialize TensorBoard. Logging is turned off for this session.  Run 'pip install tensorboard' to enable logging.
# Not using distributed mode
# git:
#   sha: c3c66d05c47b40bc1e02e18b812ca71e650f5e07, status: has uncommited changes, branch: main
#
# Namespace(num_classes=13, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=15, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='c:\\Users\\user\\Documents\\Vehicle-Detection-at-R-R-\\notebooks\\Vehicle-Body-Style-Dataset-1', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=14, num_windows=4, positional_encoding_size=37, tensorboard=True, wandb=False, project=None, run=None, class_names=['Convertible', 'Crossover', 'Fastback', 'Hardtop Convertible', 'Hatchback', 'MPV', 'Minibus', 'Pickup Truck', 'SUV', 'Sedan', 'Sports', 'Wagon'], run_test=True, distributed=False)
# number of params: 31893886
# [840]
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# [840]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [840]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 438
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\autograd\python_variable_indexing.cpp:351.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\autograd\python_variable_indexing.cpp:351.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\autograd\python_variable_indexing.cpp:351.)
# Epoch: [0]  [  0/438]  eta: 2:40:45  lr: 0.000100  class_error: 75.00  loss: 9.7567 (9.7567)  loss_ce: 1.3350 (1.3350)  loss_bbox: 0.5228 (0.5228)  loss_giou: 0.2310 (0.2310)  loss_ce_0: 1.1810 (1.1810)  loss_bbox_0: 1.2172 (1.2172)  loss_giou_0: 0.4746 (0.4746)  loss_ce_1: 1.3162 (1.3162)  loss_bbox_1: 0.5731 (0.5731)  loss_giou_1: 0.2451 (0.2451)  loss_ce_enc: 1.2057 (1.2057)  loss_bbox_enc: 1.0216 (1.0216)  loss_giou_enc: 0.4333 (0.4333)  loss_ce_unscaled: 1.3350 (1.3350)  class_error_unscaled: 75.0000 (75.0000)  loss_bbox_unscaled: 0.1046 (0.1046)  loss_giou_unscaled: 0.1155 (0.1155)  cardinality_error_unscaled: 3868.7500 (3868.7500)  loss_ce_0_unscaled: 1.1810 (1.1810)  loss_bbox_0_unscaled: 0.2434 (0.2434)  loss_giou_0_unscaled: 0.2373 (0.2373)  cardinality_error_0_unscaled: 3678.5000 (3678.5000)  loss_ce_1_unscaled: 1.3162 (1.3162)  loss_bbox_1_unscaled: 0.1146 (0.1146)  loss_giou_1_unscaled: 0.1225 (0.1225)  cardinality_error_1_unscaled: 3764.5000 (3764.5000)  loss_ce_enc_unscaled: 1.2057 (1.2057)  loss_bbox_enc_unscaled: 0.2043 (0.2043)  loss_giou_enc_unscaled: 0.2166 (0.2166)  cardinality_error_enc_unscaled: 3356.5000 (3356.5000)  time: 22.0224  data: 15.5580  max mem: 14694
# Epoch: [0]  [ 10/438]  eta: 0:26:02  lr: 0.000100  class_error: 59.62  loss: 7.0271 (7.4345)  loss_ce: 1.4431 (1.4311)  loss_bbox: 0.1574 (0.1983)  loss_giou: 0.0782 (0.0971)  loss_ce_0: 1.4251 (1.3892)  loss_bbox_0: 0.1506 (0.3157)  loss_giou_0: 0.0763 (0.1351)  loss_ce_1: 1.4384 (1.4214)  loss_bbox_1: 0.1479 (0.2032)  loss_giou_1: 0.0739 (0.0973)  loss_ce_enc: 1.3440 (1.3192)  loss_bbox_enc: 0.4737 (0.5550)  loss_giou_enc: 0.2362 (0.2720)  loss_ce_unscaled: 1.4431 (1.4311)  class_error_unscaled: 73.0769 (71.3287)  loss_bbox_unscaled: 0.0315 (0.0397)  loss_giou_unscaled: 0.0391 (0.0485)  cardinality_error_unscaled: 3893.7500 (3889.2500)  loss_ce_0_unscaled: 1.4251 (1.3892)  loss_bbox_0_unscaled: 0.0301 (0.0631)  loss_giou_0_unscaled: 0.0381 (0.0675)  cardinality_error_0_unscaled: 3765.5000 (3730.3636)  loss_ce_1_unscaled: 1.4384 (1.4214)  loss_bbox_1_unscaled: 0.0296 (0.0406)  loss_giou_1_unscaled: 0.0369 (0.0487)  cardinality_error_1_unscaled: 3814.2500 (3823.3182)  loss_ce_enc_unscaled: 1.3440 (1.3192)  loss_bbox_enc_unscaled: 0.0947 (0.1110)  loss_giou_enc_unscaled: 0.1181 (0.1360)  cardinality_error_enc_unscaled: 3398.0000 (3436.5000)  time: 3.6497  data: 1.4164  max mem: 14694
# Epoch: [0]  [ 20/438]  eta: 0:19:21  lr: 0.000100  class_error: 46.15  loss: 6.9203 (7.1343)  loss_ce: 1.4549 (1.4429)  loss_bbox: 0.1170 (0.1609)  loss_giou: 0.0623 (0.0818)  loss_ce_0: 1.4404 (1.4193)  loss_bbox_0: 0.1397 (0.2256)  loss_giou_0: 0.0683 (0.1017)  loss_ce_1: 1.4419 (1.4334)  loss_bbox_1: 0.1152 (0.1616)  loss_giou_1: 0.0551 (0.0799)  loss_ce_enc: 1.3604 (1.3511)  loss_bbox_enc: 0.3818 (0.4511)  loss_giou_enc: 0.2012 (0.2250)  loss_ce_unscaled: 1.4549 (1.4429)  class_error_unscaled: 67.3077 (67.4908)  loss_bbox_unscaled: 0.0234 (0.0322)  loss_giou_unscaled: 0.0311 (0.0409)  cardinality_error_unscaled: 3898.5000 (3893.7024)  loss_ce_0_unscaled: 1.4404 (1.4193)  loss_bbox_0_unscaled: 0.0279 (0.0451)  loss_giou_0_unscaled: 0.0342 (0.0508)  cardinality_error_0_unscaled: 3814.0000 (3784.1548)  loss_ce_1_unscaled: 1.4419 (1.4334)  loss_bbox_1_unscaled: 0.0230 (0.0323)  loss_giou_1_unscaled: 0.0275 (0.0400)  cardinality_error_1_unscaled: 3872.2500 (3847.7381)  loss_ce_enc_unscaled: 1.3604 (1.3511)  loss_bbox_enc_unscaled: 0.0764 (0.0902)  loss_giou_enc_unscaled: 0.1006 (0.1125)  cardinality_error_enc_unscaled: 3554.7500 (3529.0714)  time: 1.8166  data: 0.0025  max mem: 14694
# Epoch: [0]  [ 30/438]  eta: 0:16:47  lr: 0.000100  class_error: 3.85  loss: 6.6571 (6.9713)  loss_ce: 1.4549 (1.4501)  loss_bbox: 0.1024 (0.1415)  loss_giou: 0.0573 (0.0723)  loss_ce_0: 1.4606 (1.4380)  loss_bbox_0: 0.1007 (0.1873)  loss_giou_0: 0.0531 (0.0872)  loss_ce_1: 1.4419 (1.4359)  loss_bbox_1: 0.0934 (0.1430)  loss_giou_1: 0.0511 (0.0720)  loss_ce_enc: 1.4073 (1.3740)  loss_bbox_enc: 0.2534 (0.3775)  loss_giou_enc: 0.1405 (0.1925)  loss_ce_unscaled: 1.4549 (1.4501)  class_error_unscaled: 57.6923 (61.4144)  loss_bbox_unscaled: 0.0205 (0.0283)  loss_giou_unscaled: 0.0287 (0.0361)  cardinality_error_unscaled: 3898.0000 (3886.4355)  loss_ce_0_unscaled: 1.4606 (1.4380)  loss_bbox_0_unscaled: 0.0201 (0.0375)  loss_giou_0_unscaled: 0.0266 (0.0436)  cardinality_error_0_unscaled: 3839.0000 (3799.1290)  loss_ce_1_unscaled: 1.4419 (1.4359)  loss_bbox_1_unscaled: 0.0187 (0.0286)  loss_giou_1_unscaled: 0.0255 (0.0360)  cardinality_error_1_unscaled: 3882.7500 (3860.8145)  loss_ce_enc_unscaled: 1.4073 (1.3740)  loss_bbox_enc_unscaled: 0.0507 (0.0755)  loss_giou_enc_unscaled: 0.0702 (0.0962)  cardinality_error_enc_unscaled: 3709.2500 (3612.2661)  time: 1.8197  data: 0.0027  max mem: 14694
# Epoch: [0]  [ 40/438]  eta: 0:15:18  lr: 0.000100  class_error: 50.00  loss: 6.5822 (6.8852)  loss_ce: 1.4418 (1.4456)  loss_bbox: 0.0987 (0.1342)  loss_giou: 0.0497 (0.0687)  loss_ce_0: 1.4758 (1.4485)  loss_bbox_0: 0.1003 (0.1663)  loss_giou_0: 0.0497 (0.0789)  loss_ce_1: 1.4223 (1.4301)  loss_bbox_1: 0.0934 (0.1345)  loss_giou_1: 0.0481 (0.0679)  loss_ce_enc: 1.4243 (1.3864)  loss_bbox_enc: 0.2200 (0.3466)  loss_giou_enc: 0.1209 (0.1777)  loss_ce_unscaled: 1.4418 (1.4456)  class_error_unscaled: 51.9231 (60.5535)  loss_bbox_unscaled: 0.0197 (0.0268)  loss_giou_unscaled: 0.0249 (0.0343)  cardinality_error_unscaled: 3830.7500 (3812.4695)  loss_ce_0_unscaled: 1.4758 (1.4485)  loss_bbox_0_unscaled: 0.0201 (0.0333)  loss_giou_0_unscaled: 0.0248 (0.0394)  cardinality_error_0_unscaled: 3779.7500 (3761.4390)  loss_ce_1_unscaled: 1.4223 (1.4301)  loss_bbox_1_unscaled: 0.0187 (0.0269)  loss_giou_1_unscaled: 0.0240 (0.0339)  cardinality_error_1_unscaled: 3876.5000 (3854.6707)  loss_ce_enc_unscaled: 1.4243 (1.3864)  loss_bbox_enc_unscaled: 0.0440 (0.0693)  loss_giou_enc_unscaled: 0.0605 (0.0889)  cardinality_error_enc_unscaled: 3811.0000 (3659.2317)  time: 1.8113  data: 0.0029  max mem: 14694
# Epoch: [0]  [ 50/438]  eta: 0:14:16  lr: 0.000100  class_error: 57.69  loss: 6.5234 (6.8201)  loss_ce: 1.4242 (1.4334)  loss_bbox: 0.0936 (0.1285)  loss_giou: 0.0497 (0.0655)  loss_ce_0: 1.4781 (1.4561)  loss_bbox_0: 0.0904 (0.1550)  loss_giou_0: 0.0497 (0.0742)  loss_ce_1: 1.4096 (1.4234)  loss_bbox_1: 0.0852 (0.1294)  loss_giou_1: 0.0455 (0.0651)  loss_ce_enc: 1.4340 (1.3959)  loss_bbox_enc: 0.2187 (0.3256)  loss_giou_enc: 0.1197 (0.1681)  loss_ce_unscaled: 1.4242 (1.4334)  class_error_unscaled: 57.6923 (60.1056)  loss_bbox_unscaled: 0.0187 (0.0257)  loss_giou_unscaled: 0.0249 (0.0328)  cardinality_error_unscaled: 3333.0000 (3692.1373)  loss_ce_0_unscaled: 1.4781 (1.4561)  loss_bbox_0_unscaled: 0.0181 (0.0310)  loss_giou_0_unscaled: 0.0248 (0.0371)  cardinality_error_0_unscaled: 3556.7500 (3703.1716)  loss_ce_1_unscaled: 1.4096 (1.4234)  loss_bbox_1_unscaled: 0.0170 (0.0259)  loss_giou_1_unscaled: 0.0228 (0.0325)  cardinality_error_1_unscaled: 3829.5000 (3838.7255)  loss_ce_enc_unscaled: 1.4340 (1.3959)  loss_bbox_enc_unscaled: 0.0437 (0.0651)  loss_giou_enc_unscaled: 0.0599 (0.0841)  cardinality_error_enc_unscaled: 3798.5000 (3682.8333)  time: 1.8026  data: 0.0025  max mem: 14694
# Epoch: [0]  [ 60/438]  eta: 0:13:30  lr: 0.000100  class_error: 57.69  loss: 6.4220 (6.7516)  loss_ce: 1.3492 (1.4176)  loss_bbox: 0.0925 (0.1241)  loss_giou: 0.0452 (0.0629)  loss_ce_0: 1.4757 (1.4586)  loss_bbox_0: 0.0904 (0.1473)  loss_giou_0: 0.0503 (0.0707)  loss_ce_1: 1.3737 (1.4098)  loss_bbox_1: 0.0852 (0.1259)  loss_giou_1: 0.0440 (0.0628)  loss_ce_enc: 1.4463 (1.4057)  loss_bbox_enc: 0.2025 (0.3070)  loss_giou_enc: 0.1162 (0.1593)  loss_ce_unscaled: 1.3492 (1.4176)  class_error_unscaled: 57.6923 (60.1198)  loss_bbox_unscaled: 0.0185 (0.0248)  loss_giou_unscaled: 0.0226 (0.0314)  cardinality_error_unscaled: 3005.7500 (3546.1475)  loss_ce_0_unscaled: 1.4757 (1.4586)  loss_bbox_0_unscaled: 0.0181 (0.0295)  loss_giou_0_unscaled: 0.0251 (0.0353)  cardinality_error_0_unscaled: 3401.5000 (3630.0082)  loss_ce_1_unscaled: 1.3737 (1.4098)  loss_bbox_1_unscaled: 0.0170 (0.0252)  loss_giou_1_unscaled: 0.0220 (0.0314)  cardinality_error_1_unscaled: 3818.7500 (3836.5902)  loss_ce_enc_unscaled: 1.4463 (1.4057)  loss_bbox_enc_unscaled: 0.0405 (0.0614)  loss_giou_enc_unscaled: 0.0581 (0.0796)  cardinality_error_enc_unscaled: 3795.2500 (3701.5205)  time: 1.8086  data: 0.0022  max mem: 14694
# Epoch: [0]  [ 70/438]  eta: 0:12:54  lr: 0.000100  class_error: 44.23  loss: 6.2915 (6.6760)  loss_ce: 1.3076 (1.3955)  loss_bbox: 0.0932 (0.1197)  loss_giou: 0.0452 (0.0611)  loss_ce_0: 1.4675 (1.4591)  loss_bbox_0: 0.0945 (0.1395)  loss_giou_0: 0.0471 (0.0675)  loss_ce_1: 1.3284 (1.3952)  loss_bbox_1: 0.0967 (0.1213)  loss_giou_1: 0.0440 (0.0608)  loss_ce_enc: 1.4621 (1.4144)  loss_bbox_enc: 0.1946 (0.2899)  loss_giou_enc: 0.1052 (0.1520)  loss_ce_unscaled: 1.3076 (1.3955)  class_error_unscaled: 53.8462 (58.8841)  loss_bbox_unscaled: 0.0186 (0.0239)  loss_giou_unscaled: 0.0226 (0.0306)  cardinality_error_unscaled: 2881.2500 (3467.0211)  loss_ce_0_unscaled: 1.4675 (1.4591)  loss_bbox_0_unscaled: 0.0189 (0.0279)  loss_giou_0_unscaled: 0.0235 (0.0338)  cardinality_error_0_unscaled: 3344.7500 (3593.3979)  loss_ce_1_unscaled: 1.3284 (1.3952)  loss_bbox_1_unscaled: 0.0193 (0.0243)  loss_giou_1_unscaled: 0.0220 (0.0304)  cardinality_error_1_unscaled: 3839.0000 (3837.9718)  loss_ce_enc_unscaled: 1.4621 (1.4144)  loss_bbox_enc_unscaled: 0.0389 (0.0580)  loss_giou_enc_unscaled: 0.0526 (0.0760)  cardinality_error_enc_unscaled: 3786.0000 (3709.8415)  time: 1.8416  data: 0.0021  max mem: 14694
# Epoch: [0]  [ 80/438]  eta: 0:12:23  lr: 0.000100  class_error: 23.08  loss: 6.1662 (6.6056)  loss_ce: 1.2358 (1.3690)  loss_bbox: 0.0910 (0.1168)  loss_giou: 0.0469 (0.0597)  loss_ce_0: 1.4675 (1.4594)  loss_bbox_0: 0.0903 (0.1350)  loss_giou_0: 0.0483 (0.0660)  loss_ce_1: 1.2961 (1.3766)  loss_bbox_1: 0.0904 (0.1187)  loss_giou_1: 0.0444 (0.0596)  loss_ce_enc: 1.4744 (1.4226)  loss_bbox_enc: 0.1872 (0.2762)  loss_giou_enc: 0.1033 (0.1459)  loss_ce_unscaled: 1.2358 (1.3690)  class_error_unscaled: 51.9231 (58.0722)  loss_bbox_unscaled: 0.0182 (0.0234)  loss_giou_unscaled: 0.0235 (0.0299)  cardinality_error_unscaled: 3088.5000 (3437.4259)  loss_ce_0_unscaled: 1.4675 (1.4594)  loss_bbox_0_unscaled: 0.0181 (0.0270)  loss_giou_0_unscaled: 0.0242 (0.0330)  cardinality_error_0_unscaled: 3411.5000 (3572.0185)  loss_ce_1_unscaled: 1.2961 (1.3766)  loss_bbox_1_unscaled: 0.0181 (0.0237)  loss_giou_1_unscaled: 0.0222 (0.0298)  cardinality_error_1_unscaled: 3839.7500 (3834.2006)  loss_ce_enc_unscaled: 1.4744 (1.4226)  loss_bbox_enc_unscaled: 0.0374 (0.0552)  loss_giou_enc_unscaled: 0.0516 (0.0730)  cardinality_error_enc_unscaled: 3718.5000 (3702.8580)  time: 1.8714  data: 0.0027  max mem: 14694
# Epoch: [0]  [ 90/438]  eta: 0:11:52  lr: 0.000100  class_error: 75.00  loss: 6.1429 (6.5496)  loss_ce: 1.2582 (1.3543)  loss_bbox: 0.0875 (0.1143)  loss_giou: 0.0467 (0.0581)  loss_ce_0: 1.4385 (1.4561)  loss_bbox_0: 0.0945 (0.1310)  loss_giou_0: 0.0502 (0.0639)  loss_ce_1: 1.2675 (1.3609)  loss_bbox_1: 0.0913 (0.1168)  loss_giou_1: 0.0462 (0.0583)  loss_ce_enc: 1.4878 (1.4318)  loss_bbox_enc: 0.1685 (0.2645)  loss_giou_enc: 0.0931 (0.1397)  loss_ce_unscaled: 1.2582 (1.3543)  class_error_unscaled: 59.6154 (59.1293)  loss_bbox_unscaled: 0.0175 (0.0229)  loss_giou_unscaled: 0.0233 (0.0290)  cardinality_error_unscaled: 3125.0000 (3386.8022)  loss_ce_0_unscaled: 1.4385 (1.4561)  loss_bbox_0_unscaled: 0.0189 (0.0262)  loss_giou_0_unscaled: 0.0251 (0.0320)  cardinality_error_0_unscaled: 3531.7500 (3574.7390)  loss_ce_1_unscaled: 1.2675 (1.3609)  loss_bbox_1_unscaled: 0.0183 (0.0234)  loss_giou_1_unscaled: 0.0231 (0.0291)  cardinality_error_1_unscaled: 3826.0000 (3833.2115)  loss_ce_enc_unscaled: 1.4878 (1.4318)  loss_bbox_enc_unscaled: 0.0337 (0.0529)  loss_giou_enc_unscaled: 0.0465 (0.0699)  cardinality_error_enc_unscaled: 3659.7500 (3697.5934)  time: 1.8442  data: 0.0034  max mem: 14694
# Epoch: [0]  [100/438]  eta: 0:11:24  lr: 0.000100  class_error: 28.85  loss: 6.1275 (6.5395)  loss_ce: 1.2150 (1.3384)  loss_bbox: 0.0907 (0.1189)  loss_giou: 0.0497 (0.0620)  loss_ce_0: 1.4143 (1.4476)  loss_bbox_0: 0.0871 (0.1354)  loss_giou_0: 0.0507 (0.0692)  loss_ce_1: 1.2341 (1.3473)  loss_bbox_1: 0.0947 (0.1215)  loss_giou_1: 0.0490 (0.0624)  loss_ce_enc: 1.5059 (1.4361)  loss_bbox_enc: 0.1659 (0.2607)  loss_giou_enc: 0.0900 (0.1401)  loss_ce_unscaled: 1.2150 (1.3384)  class_error_unscaled: 63.4615 (58.5872)  loss_bbox_unscaled: 0.0181 (0.0238)  loss_giou_unscaled: 0.0248 (0.0310)  cardinality_error_unscaled: 2819.2500 (3322.3564)  loss_ce_0_unscaled: 1.4143 (1.4476)  loss_bbox_0_unscaled: 0.0174 (0.0271)  loss_giou_0_unscaled: 0.0254 (0.0346)  cardinality_error_0_unscaled: 3593.7500 (3570.2550)  loss_ce_1_unscaled: 1.2341 (1.3473)  loss_bbox_1_unscaled: 0.0189 (0.0243)  loss_giou_1_unscaled: 0.0245 (0.0312)  cardinality_error_1_unscaled: 3843.7500 (3834.5990)  loss_ce_enc_unscaled: 1.5059 (1.4361)  loss_bbox_enc_unscaled: 0.0332 (0.0521)  loss_giou_enc_unscaled: 0.0450 (0.0700)  cardinality_error_enc_unscaled: 3659.7500 (3695.4035)  time: 1.8165  data: 0.0036  max mem: 14694
# Epoch: [0]  [110/438]  eta: 0:10:59  lr: 0.000100  class_error: 57.69  loss: 5.9345 (6.4842)  loss_ce: 1.1898 (1.3225)  loss_bbox: 0.0905 (0.1158)  loss_giou: 0.0500 (0.0605)  loss_ce_0: 1.3743 (1.4419)  loss_bbox_0: 0.0858 (0.1314)  loss_giou_0: 0.0453 (0.0671)  loss_ce_1: 1.2106 (1.3334)  loss_bbox_1: 0.0854 (0.1182)  loss_giou_1: 0.0445 (0.0606)  loss_ce_enc: 1.5153 (1.4435)  loss_bbox_enc: 0.1698 (0.2531)  loss_giou_enc: 0.0903 (0.1364)  loss_ce_unscaled: 1.1898 (1.3225)  class_error_unscaled: 48.0769 (57.6577)  loss_bbox_unscaled: 0.0181 (0.0232)  loss_giou_unscaled: 0.0250 (0.0302)  cardinality_error_unscaled: 2697.7500 (3265.8153)  loss_ce_0_unscaled: 1.3743 (1.4419)  loss_bbox_0_unscaled: 0.0172 (0.0263)  loss_giou_0_unscaled: 0.0226 (0.0335)  cardinality_error_0_unscaled: 3565.7500 (3574.6284)  loss_ce_1_unscaled: 1.2106 (1.3334)  loss_bbox_1_unscaled: 0.0171 (0.0236)  loss_giou_1_unscaled: 0.0223 (0.0303)  cardinality_error_1_unscaled: 3863.5000 (3837.6419)  loss_ce_enc_unscaled: 1.5153 (1.4435)  loss_bbox_enc_unscaled: 0.0340 (0.0506)  loss_giou_enc_unscaled: 0.0452 (0.0682)  cardinality_error_enc_unscaled: 3625.5000 (3686.2590)  time: 1.8401  data: 0.0034  max mem: 14694
# Epoch: [0]  [120/438]  eta: 0:10:34  lr: 0.000100  class_error: 82.69  loss: 5.9433 (6.4469)  loss_ce: 1.1919 (1.3114)  loss_bbox: 0.0860 (0.1151)  loss_giou: 0.0459 (0.0599)  loss_ce_0: 1.3686 (1.4354)  loss_bbox_0: 0.0937 (0.1301)  loss_giou_0: 0.0453 (0.0666)  loss_ce_1: 1.1943 (1.3212)  loss_bbox_1: 0.0839 (0.1171)  loss_giou_1: 0.0417 (0.0600)  loss_ce_enc: 1.5149 (1.4496)  loss_bbox_enc: 0.1775 (0.2471)  loss_giou_enc: 0.0988 (0.1333)  loss_ce_unscaled: 1.1919 (1.3114)  class_error_unscaled: 51.9231 (58.3121)  loss_bbox_unscaled: 0.0172 (0.0230)  loss_giou_unscaled: 0.0229 (0.0300)  cardinality_error_unscaled: 2382.5000 (3178.8657)  loss_ce_0_unscaled: 1.3686 (1.4354)  loss_bbox_0_unscaled: 0.0187 (0.0260)  loss_giou_0_unscaled: 0.0226 (0.0333)  cardinality_error_0_unscaled: 3617.7500 (3573.1818)  loss_ce_1_unscaled: 1.1943 (1.3212)  loss_bbox_1_unscaled: 0.0168 (0.0234)  loss_giou_1_unscaled: 0.0208 (0.0300)  cardinality_error_1_unscaled: 3870.5000 (3838.9153)  loss_ce_enc_unscaled: 1.5149 (1.4496)  loss_bbox_enc_unscaled: 0.0355 (0.0494)  loss_giou_enc_unscaled: 0.0494 (0.0666)  cardinality_error_enc_unscaled: 3641.0000 (3689.9091)  time: 1.8491  data: 0.0031  max mem: 14694
# Epoch: [0]  [130/438]  eta: 0:10:11  lr: 0.000100  class_error: 36.54  loss: 5.9679 (6.3990)  loss_ce: 1.2014 (1.2957)  loss_bbox: 0.0882 (0.1127)  loss_giou: 0.0446 (0.0586)  loss_ce_0: 1.3478 (1.4287)  loss_bbox_0: 0.0978 (0.1273)  loss_giou_0: 0.0512 (0.0654)  loss_ce_1: 1.1816 (1.3077)  loss_bbox_1: 0.0857 (0.1149)  loss_giou_1: 0.0395 (0.0589)  loss_ce_enc: 1.5246 (1.4560)  loss_bbox_enc: 0.1836 (0.2420)  loss_giou_enc: 0.0987 (0.1310)  loss_ce_unscaled: 1.2014 (1.2957)  class_error_unscaled: 55.7692 (57.5161)  loss_bbox_unscaled: 0.0176 (0.0225)  loss_giou_unscaled: 0.0223 (0.0293)  cardinality_error_unscaled: 2280.7500 (3114.2366)  loss_ce_0_unscaled: 1.3478 (1.4287)  loss_bbox_0_unscaled: 0.0196 (0.0255)  loss_giou_0_unscaled: 0.0256 (0.0327)  cardinality_error_0_unscaled: 3626.0000 (3577.4561)  loss_ce_1_unscaled: 1.1816 (1.3077)  loss_bbox_1_unscaled: 0.0171 (0.0230)  loss_giou_1_unscaled: 0.0197 (0.0295)  cardinality_error_1_unscaled: 3869.0000 (3841.1469)  loss_ce_enc_unscaled: 1.5246 (1.4560)  loss_bbox_enc_unscaled: 0.0367 (0.0484)  loss_giou_enc_unscaled: 0.0493 (0.0655)  cardinality_error_enc_unscaled: 3722.2500 (3692.0935)  time: 1.8470  data: 0.0039  max mem: 14694
# Epoch: [0]  [140/438]  eta: 0:09:50  lr: 0.000100  class_error: 25.00  loss: 5.8889 (6.3517)  loss_ce: 1.1599 (1.2778)  loss_bbox: 0.0844 (0.1113)  loss_giou: 0.0439 (0.0576)  loss_ce_0: 1.3513 (1.4230)  loss_bbox_0: 0.0915 (0.1260)  loss_giou_0: 0.0480 (0.0645)  loss_ce_1: 1.1698 (1.2930)  loss_bbox_1: 0.0869 (0.1135)  loss_giou_1: 0.0425 (0.0580)  loss_ce_enc: 1.5327 (1.4615)  loss_bbox_enc: 0.1668 (0.2370)  loss_giou_enc: 0.0932 (0.1284)  loss_ce_unscaled: 1.1599 (1.2778)  class_error_unscaled: 48.0769 (57.6514)  loss_bbox_unscaled: 0.0169 (0.0223)  loss_giou_unscaled: 0.0220 (0.0288)  cardinality_error_unscaled: 2344.5000 (3066.9805)  loss_ce_0_unscaled: 1.3513 (1.4230)  loss_bbox_0_unscaled: 0.0183 (0.0252)  loss_giou_0_unscaled: 0.0240 (0.0322)  cardinality_error_0_unscaled: 3644.5000 (3578.7553)  loss_ce_1_unscaled: 1.1698 (1.2930)  loss_bbox_1_unscaled: 0.0174 (0.0227)  loss_giou_1_unscaled: 0.0213 (0.0290)  cardinality_error_1_unscaled: 3870.2500 (3843.3972)  loss_ce_enc_unscaled: 1.5327 (1.4615)  loss_bbox_enc_unscaled: 0.0334 (0.0474)  loss_giou_enc_unscaled: 0.0466 (0.0642)  cardinality_error_enc_unscaled: 3708.7500 (3693.3050)  time: 1.9009  data: 0.0040  max mem: 14694
# Epoch: [0]  [150/438]  eta: 0:09:27  lr: 0.000100  class_error: 61.54  loss: 5.9098 (6.3209)  loss_ce: 1.1269 (1.2678)  loss_bbox: 0.0823 (0.1097)  loss_giou: 0.0439 (0.0568)  loss_ce_0: 1.3494 (1.4179)  loss_bbox_0: 0.0969 (0.1245)  loss_giou_0: 0.0508 (0.0639)  loss_ce_1: 1.1636 (1.2845)  loss_bbox_1: 0.0869 (0.1119)  loss_giou_1: 0.0409 (0.0573)  loss_ce_enc: 1.5295 (1.4659)  loss_bbox_enc: 0.1691 (0.2336)  loss_giou_enc: 0.1001 (0.1270)  loss_ce_unscaled: 1.1269 (1.2678)  class_error_unscaled: 51.9231 (57.4885)  loss_bbox_unscaled: 0.0165 (0.0219)  loss_giou_unscaled: 0.0220 (0.0284)  cardinality_error_unscaled: 2286.5000 (3020.0944)  loss_ce_0_unscaled: 1.3494 (1.4179)  loss_bbox_0_unscaled: 0.0194 (0.0249)  loss_giou_0_unscaled: 0.0254 (0.0320)  cardinality_error_0_unscaled: 3649.2500 (3586.1192)  loss_ce_1_unscaled: 1.1636 (1.2845)  loss_bbox_1_unscaled: 0.0174 (0.0224)  loss_giou_1_unscaled: 0.0204 (0.0286)  cardinality_error_1_unscaled: 3879.0000 (3845.7699)  loss_ce_enc_unscaled: 1.5295 (1.4659)  loss_bbox_enc_unscaled: 0.0338 (0.0467)  loss_giou_enc_unscaled: 0.0500 (0.0635)  cardinality_error_enc_unscaled: 3713.7500 (3696.6209)  time: 1.8844  data: 0.0028  max mem: 14694
# Epoch: [0]  [160/438]  eta: 0:09:04  lr: 0.000100  class_error: 65.38  loss: 5.9192 (6.2959)  loss_ce: 1.1545 (1.2603)  loss_bbox: 0.0882 (0.1091)  loss_giou: 0.0457 (0.0566)  loss_ce_0: 1.3340 (1.4117)  loss_bbox_0: 0.1026 (0.1245)  loss_giou_0: 0.0537 (0.0638)  loss_ce_1: 1.1538 (1.2760)  loss_bbox_1: 0.0858 (0.1111)  loss_giou_1: 0.0430 (0.0569)  loss_ce_enc: 1.5332 (1.4702)  loss_bbox_enc: 0.1835 (0.2305)  loss_giou_enc: 0.1036 (0.1253)  loss_ce_unscaled: 1.1545 (1.2603)  class_error_unscaled: 51.9231 (57.7043)  loss_bbox_unscaled: 0.0176 (0.0218)  loss_giou_unscaled: 0.0229 (0.0283)  cardinality_error_unscaled: 2290.0000 (2981.3913)  loss_ce_0_unscaled: 1.3340 (1.4117)  loss_bbox_0_unscaled: 0.0205 (0.0249)  loss_giou_0_unscaled: 0.0268 (0.0319)  cardinality_error_0_unscaled: 3621.7500 (3579.9301)  loss_ce_1_unscaled: 1.1538 (1.2760)  loss_bbox_1_unscaled: 0.0172 (0.0222)  loss_giou_1_unscaled: 0.0215 (0.0285)  cardinality_error_1_unscaled: 3883.0000 (3848.2640)  loss_ce_enc_unscaled: 1.5332 (1.4702)  loss_bbox_enc_unscaled: 0.0367 (0.0461)  loss_giou_enc_unscaled: 0.0518 (0.0627)  cardinality_error_enc_unscaled: 3733.7500 (3699.2780)  time: 1.8010  data: 0.0023  max mem: 14694
# Epoch: [0]  [170/438]  eta: 0:08:42  lr: 0.000100  class_error: 25.00  loss: 5.9883 (6.2756)  loss_ce: 1.1583 (1.2529)  loss_bbox: 0.0902 (0.1091)  loss_giou: 0.0445 (0.0563)  loss_ce_0: 1.3263 (1.4071)  loss_bbox_0: 0.1070 (0.1242)  loss_giou_0: 0.0542 (0.0635)  loss_ce_1: 1.1604 (1.2693)  loss_bbox_1: 0.0896 (0.1109)  loss_giou_1: 0.0490 (0.0567)  loss_ce_enc: 1.5325 (1.4737)  loss_bbox_enc: 0.1835 (0.2279)  loss_giou_enc: 0.0974 (0.1240)  loss_ce_unscaled: 1.1583 (1.2529)  class_error_unscaled: 55.7692 (57.3437)  loss_bbox_unscaled: 0.0180 (0.0218)  loss_giou_unscaled: 0.0222 (0.0282)  cardinality_error_unscaled: 2404.0000 (2953.3772)  loss_ce_0_unscaled: 1.3263 (1.4071)  loss_bbox_0_unscaled: 0.0214 (0.0248)  loss_giou_0_unscaled: 0.0271 (0.0317)  cardinality_error_0_unscaled: 3719.0000 (3592.1067)  loss_ce_1_unscaled: 1.1604 (1.2693)  loss_bbox_1_unscaled: 0.0179 (0.0222)  loss_giou_1_unscaled: 0.0245 (0.0284)  cardinality_error_1_unscaled: 3888.0000 (3850.2895)  loss_ce_enc_unscaled: 1.5325 (1.4737)  loss_bbox_enc_unscaled: 0.0367 (0.0456)  loss_giou_enc_unscaled: 0.0487 (0.0620)  cardinality_error_enc_unscaled: 3781.2500 (3705.7939)  time: 1.7778  data: 0.0024  max mem: 14694
# Epoch: [0]  [180/438]  eta: 0:08:20  lr: 0.000100  class_error: 88.46  loss: 5.6762 (6.2377)  loss_ce: 1.1175 (1.2410)  loss_bbox: 0.0884 (0.1075)  loss_giou: 0.0442 (0.0558)  loss_ce_0: 1.2797 (1.3975)  loss_bbox_0: 0.1177 (0.1245)  loss_giou_0: 0.0553 (0.0635)  loss_ce_1: 1.0974 (1.2578)  loss_bbox_1: 0.0894 (0.1095)  loss_giou_1: 0.0490 (0.0562)  loss_ce_enc: 1.5357 (1.4774)  loss_bbox_enc: 0.1766 (0.2248)  loss_giou_enc: 0.0944 (0.1223)  loss_ce_unscaled: 1.1175 (1.2410)  class_error_unscaled: 44.2308 (56.7680)  loss_bbox_unscaled: 0.0177 (0.0215)  loss_giou_unscaled: 0.0221 (0.0279)  cardinality_error_unscaled: 2244.2500 (2907.6906)  loss_ce_0_unscaled: 1.2797 (1.3975)  loss_bbox_0_unscaled: 0.0235 (0.0249)  loss_giou_0_unscaled: 0.0277 (0.0317)  cardinality_error_0_unscaled: 3757.5000 (3598.4047)  loss_ce_1_unscaled: 1.0974 (1.2578)  loss_bbox_1_unscaled: 0.0179 (0.0219)  loss_giou_1_unscaled: 0.0245 (0.0281)  cardinality_error_1_unscaled: 3872.5000 (3850.5912)  loss_ce_enc_unscaled: 1.5357 (1.4774)  loss_bbox_enc_unscaled: 0.0353 (0.0450)  loss_giou_enc_unscaled: 0.0472 (0.0612)  cardinality_error_enc_unscaled: 3770.5000 (3703.4530)  time: 1.7787  data: 0.0023  max mem: 14694
# Epoch: [0]  [190/438]  eta: 0:07:59  lr: 0.000100  class_error: 30.77  loss: 5.6392 (6.2167)  loss_ce: 1.0769 (1.2354)  loss_bbox: 0.0789 (0.1074)  loss_giou: 0.0442 (0.0555)  loss_ce_0: 1.2395 (1.3905)  loss_bbox_0: 0.1231 (0.1246)  loss_giou_0: 0.0594 (0.0633)  loss_ce_1: 1.0974 (1.2504)  loss_bbox_1: 0.0829 (0.1096)  loss_giou_1: 0.0450 (0.0560)  loss_ce_enc: 1.5357 (1.4802)  loss_bbox_enc: 0.1775 (0.2226)  loss_giou_enc: 0.0969 (0.1212)  loss_ce_unscaled: 1.0769 (1.2354)  class_error_unscaled: 46.1538 (56.6653)  loss_bbox_unscaled: 0.0158 (0.0215)  loss_giou_unscaled: 0.0221 (0.0277)  cardinality_error_unscaled: 1905.2500 (2848.0903)  loss_ce_0_unscaled: 1.2395 (1.3905)  loss_bbox_0_unscaled: 0.0246 (0.0249)  loss_giou_0_unscaled: 0.0297 (0.0317)  cardinality_error_0_unscaled: 3606.7500 (3592.0864)  loss_ce_1_unscaled: 1.0974 (1.2504)  loss_bbox_1_unscaled: 0.0166 (0.0219)  loss_giou_1_unscaled: 0.0225 (0.0280)  cardinality_error_1_unscaled: 3846.7500 (3850.0942)  loss_ce_enc_unscaled: 1.5357 (1.4802)  loss_bbox_enc_unscaled: 0.0355 (0.0445)  loss_giou_enc_unscaled: 0.0484 (0.0606)  cardinality_error_enc_unscaled: 3643.7500 (3698.6165)  time: 1.7810  data: 0.0023  max mem: 14694
# Epoch: [0]  [200/438]  eta: 0:07:37  lr: 0.000100  class_error: 55.77  loss: 5.8270 (6.1963)  loss_ce: 1.1553 (1.2285)  loss_bbox: 0.0838 (0.1078)  loss_giou: 0.0469 (0.0554)  loss_ce_0: 1.2412 (1.3820)  loss_bbox_0: 0.1289 (0.1256)  loss_giou_0: 0.0606 (0.0634)  loss_ce_1: 1.1304 (1.2434)  loss_bbox_1: 0.0890 (0.1100)  loss_giou_1: 0.0448 (0.0559)  loss_ce_enc: 1.5268 (1.4823)  loss_bbox_enc: 0.1866 (0.2215)  loss_giou_enc: 0.1001 (0.1205)  loss_ce_unscaled: 1.1553 (1.2285)  class_error_unscaled: 51.9231 (56.5155)  loss_bbox_unscaled: 0.0168 (0.0216)  loss_giou_unscaled: 0.0234 (0.0277)  cardinality_error_unscaled: 1956.2500 (2815.4950)  loss_ce_0_unscaled: 1.2412 (1.3820)  loss_bbox_0_unscaled: 0.0258 (0.0251)  loss_giou_0_unscaled: 0.0303 (0.0317)  cardinality_error_0_unscaled: 3403.2500 (3573.1269)  loss_ce_1_unscaled: 1.1304 (1.2434)  loss_bbox_1_unscaled: 0.0178 (0.0220)  loss_giou_1_unscaled: 0.0224 (0.0280)  cardinality_error_1_unscaled: 3850.5000 (3850.9117)  loss_ce_enc_unscaled: 1.5268 (1.4823)  loss_bbox_enc_unscaled: 0.0373 (0.0443)  loss_giou_enc_unscaled: 0.0500 (0.0602)  cardinality_error_enc_unscaled: 3573.5000 (3688.2127)  time: 1.7772  data: 0.0024  max mem: 14694
# Epoch: [0]  [210/438]  eta: 0:07:16  lr: 0.000100  class_error: 25.00  loss: 5.7527 (6.1706)  loss_ce: 1.0863 (1.2206)  loss_bbox: 0.0838 (0.1065)  loss_giou: 0.0425 (0.0548)  loss_ce_0: 1.2388 (1.3760)  loss_bbox_0: 0.1174 (0.1250)  loss_giou_0: 0.0569 (0.0631)  loss_ce_1: 1.1404 (1.2361)  loss_bbox_1: 0.0849 (0.1088)  loss_giou_1: 0.0427 (0.0554)  loss_ce_enc: 1.5304 (1.4846)  loss_bbox_enc: 0.1898 (0.2201)  loss_giou_enc: 0.0973 (0.1195)  loss_ce_unscaled: 1.0863 (1.2206)  class_error_unscaled: 51.9231 (56.0700)  loss_bbox_unscaled: 0.0168 (0.0213)  loss_giou_unscaled: 0.0212 (0.0274)  cardinality_error_unscaled: 1872.7500 (2767.9313)  loss_ce_0_unscaled: 1.2388 (1.3760)  loss_bbox_0_unscaled: 0.0235 (0.0250)  loss_giou_0_unscaled: 0.0285 (0.0315)  cardinality_error_0_unscaled: 3327.0000 (3560.5225)  loss_ce_1_unscaled: 1.1404 (1.2361)  loss_bbox_1_unscaled: 0.0170 (0.0218)  loss_giou_1_unscaled: 0.0214 (0.0277)  cardinality_error_1_unscaled: 3865.5000 (3852.0415)  loss_ce_enc_unscaled: 1.5304 (1.4846)  loss_bbox_enc_unscaled: 0.0380 (0.0440)  loss_giou_enc_unscaled: 0.0487 (0.0598)  cardinality_error_enc_unscaled: 3455.2500 (3675.4336)  time: 1.7724  data: 0.0024  max mem: 14694
# Epoch: [0]  [220/438]  eta: 0:06:56  lr: 0.000100  class_error: 50.00  loss: 5.6589 (6.1494)  loss_ce: 1.0810 (1.2141)  loss_bbox: 0.0866 (0.1061)  loss_giou: 0.0460 (0.0547)  loss_ce_0: 1.2303 (1.3682)  loss_bbox_0: 0.1120 (0.1253)  loss_giou_0: 0.0600 (0.0633)  loss_ce_1: 1.0861 (1.2298)  loss_bbox_1: 0.0912 (0.1086)  loss_giou_1: 0.0445 (0.0553)  loss_ce_enc: 1.5264 (1.4866)  loss_bbox_enc: 0.1829 (0.2184)  loss_giou_enc: 0.1002 (0.1189)  loss_ce_unscaled: 1.0810 (1.2141)  class_error_unscaled: 50.0000 (56.0651)  loss_bbox_unscaled: 0.0173 (0.0212)  loss_giou_unscaled: 0.0230 (0.0273)  cardinality_error_unscaled: 1811.7500 (2733.7296)  loss_ce_0_unscaled: 1.2303 (1.3682)  loss_bbox_0_unscaled: 0.0224 (0.0251)  loss_giou_0_unscaled: 0.0300 (0.0316)  cardinality_error_0_unscaled: 3606.7500 (3566.6222)  loss_ce_1_unscaled: 1.0861 (1.2298)  loss_bbox_1_unscaled: 0.0182 (0.0217)  loss_giou_1_unscaled: 0.0223 (0.0277)  cardinality_error_1_unscaled: 3890.2500 (3853.5690)  loss_ce_enc_unscaled: 1.5264 (1.4866)  loss_bbox_enc_unscaled: 0.0366 (0.0437)  loss_giou_enc_unscaled: 0.0501 (0.0595)  cardinality_error_enc_unscaled: 3442.7500 (3668.4977)  time: 1.7734  data: 0.0023  max mem: 14694
# Epoch: [0]  [230/438]  eta: 0:06:35  lr: 0.000100  class_error: 15.38  loss: 5.6188 (6.1278)  loss_ce: 1.0810 (1.2079)  loss_bbox: 0.0899 (0.1054)  loss_giou: 0.0462 (0.0542)  loss_ce_0: 1.2145 (1.3617)  loss_bbox_0: 0.1192 (0.1252)  loss_giou_0: 0.0600 (0.0630)  loss_ce_1: 1.0891 (1.2238)  loss_bbox_1: 0.0992 (0.1080)  loss_giou_1: 0.0475 (0.0549)  loss_ce_enc: 1.5387 (1.4891)  loss_bbox_enc: 0.1785 (0.2166)  loss_giou_enc: 0.0960 (0.1178)  loss_ce_unscaled: 1.0810 (1.2079)  class_error_unscaled: 48.0769 (55.6943)  loss_bbox_unscaled: 0.0180 (0.0211)  loss_giou_unscaled: 0.0231 (0.0271)  cardinality_error_unscaled: 1811.7500 (2687.5076)  loss_ce_0_unscaled: 1.2145 (1.3617)  loss_bbox_0_unscaled: 0.0238 (0.0250)  loss_giou_0_unscaled: 0.0300 (0.0315)  cardinality_error_0_unscaled: 3587.2500 (3560.1840)  loss_ce_1_unscaled: 1.0891 (1.2238)  loss_bbox_1_unscaled: 0.0198 (0.0216)  loss_giou_1_unscaled: 0.0238 (0.0274)  cardinality_error_1_unscaled: 3885.0000 (3854.5465)  loss_ce_enc_unscaled: 1.5387 (1.4891)  loss_bbox_enc_unscaled: 0.0357 (0.0433)  loss_giou_enc_unscaled: 0.0480 (0.0589)  cardinality_error_enc_unscaled: 3465.5000 (3658.0368)  time: 1.7712  data: 0.0023  max mem: 14694
# Epoch: [0]  [240/438]  eta: 0:06:15  lr: 0.000100  class_error: 90.38  loss: 5.6574 (6.1131)  loss_ce: 1.1043 (1.2046)  loss_bbox: 0.0896 (0.1048)  loss_giou: 0.0444 (0.0538)  loss_ce_0: 1.2445 (1.3573)  loss_bbox_0: 0.1213 (0.1250)  loss_giou_0: 0.0581 (0.0629)  loss_ce_1: 1.1105 (1.2202)  loss_bbox_1: 0.1036 (0.1078)  loss_giou_1: 0.0472 (0.0547)  loss_ce_enc: 1.5172 (1.4897)  loss_bbox_enc: 0.1781 (0.2152)  loss_giou_enc: 0.0960 (0.1172)  loss_ce_unscaled: 1.1043 (1.2046)  class_error_unscaled: 53.8462 (55.9927)  loss_bbox_unscaled: 0.0179 (0.0210)  loss_giou_unscaled: 0.0222 (0.0269)  cardinality_error_unscaled: 1801.2500 (2660.4274)  loss_ce_0_unscaled: 1.2445 (1.3573)  loss_bbox_0_unscaled: 0.0243 (0.0250)  loss_giou_0_unscaled: 0.0290 (0.0315)  cardinality_error_0_unscaled: 3478.0000 (3561.8309)  loss_ce_1_unscaled: 1.1105 (1.2202)  loss_bbox_1_unscaled: 0.0207 (0.0216)  loss_giou_1_unscaled: 0.0236 (0.0273)  cardinality_error_1_unscaled: 3872.7500 (3855.2687)  loss_ce_enc_unscaled: 1.5172 (1.4897)  loss_bbox_enc_unscaled: 0.0356 (0.0430)  loss_giou_enc_unscaled: 0.0480 (0.0586)  cardinality_error_enc_unscaled: 3487.0000 (3655.8496)  time: 1.7712  data: 0.0023  max mem: 14694
# Epoch: [0]  [250/438]  eta: 0:05:55  lr: 0.000100  class_error: 51.92  loss: 5.7136 (6.0970)  loss_ce: 1.1077 (1.1991)  loss_bbox: 0.0932 (0.1055)  loss_giou: 0.0433 (0.0539)  loss_ce_0: 1.2183 (1.3507)  loss_bbox_0: 0.1213 (0.1249)  loss_giou_0: 0.0573 (0.0628)  loss_ce_1: 1.1131 (1.2153)  loss_bbox_1: 0.1012 (0.1083)  loss_giou_1: 0.0479 (0.0548)  loss_ce_enc: 1.5036 (1.4903)  loss_bbox_enc: 0.1882 (0.2146)  loss_giou_enc: 0.1049 (0.1168)  loss_ce_unscaled: 1.1077 (1.1991)  class_error_unscaled: 53.8462 (55.8305)  loss_bbox_unscaled: 0.0186 (0.0211)  loss_giou_unscaled: 0.0216 (0.0269)  cardinality_error_unscaled: 2227.5000 (2642.2480)  loss_ce_0_unscaled: 1.2183 (1.3507)  loss_bbox_0_unscaled: 0.0243 (0.0250)  loss_giou_0_unscaled: 0.0286 (0.0314)  cardinality_error_0_unscaled: 3404.0000 (3556.1554)  loss_ce_1_unscaled: 1.1131 (1.2153)  loss_bbox_1_unscaled: 0.0202 (0.0217)  loss_giou_1_unscaled: 0.0240 (0.0274)  cardinality_error_1_unscaled: 3872.7500 (3855.9333)  loss_ce_enc_unscaled: 1.5036 (1.4903)  loss_bbox_enc_unscaled: 0.0376 (0.0429)  loss_giou_enc_unscaled: 0.0524 (0.0584)  cardinality_error_enc_unscaled: 3610.7500 (3653.5229)  time: 1.7751  data: 0.0023  max mem: 14694
# Epoch: [0]  [260/438]  eta: 0:05:36  lr: 0.000100  class_error: 38.46  loss: 5.6746 (6.0826)  loss_ce: 1.0740 (1.1930)  loss_bbox: 0.0964 (0.1068)  loss_giou: 0.0449 (0.0541)  loss_ce_0: 1.1845 (1.3440)  loss_bbox_0: 0.1209 (0.1258)  loss_giou_0: 0.0573 (0.0631)  loss_ce_1: 1.0802 (1.2097)  loss_bbox_1: 0.0987 (0.1095)  loss_giou_1: 0.0467 (0.0550)  loss_ce_enc: 1.5098 (1.4914)  loss_bbox_enc: 0.1882 (0.2137)  loss_giou_enc: 0.1048 (0.1164)  loss_ce_unscaled: 1.0740 (1.1930)  class_error_unscaled: 48.0769 (55.4819)  loss_bbox_unscaled: 0.0193 (0.0214)  loss_giou_unscaled: 0.0224 (0.0271)  cardinality_error_unscaled: 1948.0000 (2608.5172)  loss_ce_0_unscaled: 1.1845 (1.3440)  loss_bbox_0_unscaled: 0.0242 (0.0252)  loss_giou_0_unscaled: 0.0286 (0.0315)  cardinality_error_0_unscaled: 3553.7500 (3559.4521)  loss_ce_1_unscaled: 1.0802 (1.2097)  loss_bbox_1_unscaled: 0.0197 (0.0219)  loss_giou_1_unscaled: 0.0234 (0.0275)  cardinality_error_1_unscaled: 3875.5000 (3856.7605)  loss_ce_enc_unscaled: 1.5098 (1.4914)  loss_bbox_enc_unscaled: 0.0376 (0.0427)  loss_giou_enc_unscaled: 0.0524 (0.0582)  cardinality_error_enc_unscaled: 3623.7500 (3653.2385)  time: 1.7739  data: 0.0022  max mem: 14694
# Epoch: [0]  [270/438]  eta: 0:05:16  lr: 0.000100  class_error: 69.23  loss: 5.6746 (6.0667)  loss_ce: 1.0842 (1.1892)  loss_bbox: 0.0964 (0.1064)  loss_giou: 0.0438 (0.0538)  loss_ce_0: 1.1815 (1.3383)  loss_bbox_0: 0.1130 (0.1255)  loss_giou_0: 0.0568 (0.0628)  loss_ce_1: 1.0990 (1.2064)  loss_bbox_1: 0.0918 (0.1092)  loss_giou_1: 0.0467 (0.0547)  loss_ce_enc: 1.5133 (1.4922)  loss_bbox_enc: 0.1797 (0.2125)  loss_giou_enc: 0.0990 (0.1158)  loss_ce_unscaled: 1.0842 (1.1892)  class_error_unscaled: 48.0769 (55.4428)  loss_bbox_unscaled: 0.0193 (0.0213)  loss_giou_unscaled: 0.0219 (0.0269)  cardinality_error_unscaled: 1866.7500 (2582.2694)  loss_ce_0_unscaled: 1.1815 (1.3383)  loss_bbox_0_unscaled: 0.0226 (0.0251)  loss_giou_0_unscaled: 0.0284 (0.0314)  cardinality_error_0_unscaled: 3600.5000 (3560.8681)  loss_ce_1_unscaled: 1.0990 (1.2064)  loss_bbox_1_unscaled: 0.0184 (0.0218)  loss_giou_1_unscaled: 0.0234 (0.0273)  cardinality_error_1_unscaled: 3876.0000 (3857.5120)  loss_ce_enc_unscaled: 1.5133 (1.4922)  loss_bbox_enc_unscaled: 0.0359 (0.0425)  loss_giou_enc_unscaled: 0.0495 (0.0579)  cardinality_error_enc_unscaled: 3646.7500 (3652.5351)  time: 1.7772  data: 0.0024  max mem: 14694
# Epoch: [0]  [280/438]  eta: 0:04:57  lr: 0.000100  class_error: 76.92  loss: 5.6583 (6.0518)  loss_ce: 1.0900 (1.1856)  loss_bbox: 0.0891 (0.1067)  loss_giou: 0.0433 (0.0538)  loss_ce_0: 1.1815 (1.3324)  loss_bbox_0: 0.1017 (0.1247)  loss_giou_0: 0.0494 (0.0624)  loss_ce_1: 1.1192 (1.2026)  loss_bbox_1: 0.0903 (0.1094)  loss_giou_1: 0.0432 (0.0547)  loss_ce_enc: 1.5050 (1.4927)  loss_bbox_enc: 0.1764 (0.2117)  loss_giou_enc: 0.0987 (0.1153)  loss_ce_unscaled: 1.0900 (1.1856)  class_error_unscaled: 57.6923 (55.7829)  loss_bbox_unscaled: 0.0178 (0.0213)  loss_giou_unscaled: 0.0217 (0.0269)  cardinality_error_unscaled: 1853.7500 (2548.6406)  loss_ce_0_unscaled: 1.1815 (1.3324)  loss_bbox_0_unscaled: 0.0203 (0.0249)  loss_giou_0_unscaled: 0.0247 (0.0312)  cardinality_error_0_unscaled: 3667.7500 (3562.8078)  loss_ce_1_unscaled: 1.1192 (1.2026)  loss_bbox_1_unscaled: 0.0181 (0.0219)  loss_giou_1_unscaled: 0.0216 (0.0273)  cardinality_error_1_unscaled: 3873.5000 (3857.8603)  loss_ce_enc_unscaled: 1.5050 (1.4927)  loss_bbox_enc_unscaled: 0.0353 (0.0423)  loss_giou_enc_unscaled: 0.0494 (0.0577)  cardinality_error_enc_unscaled: 3662.7500 (3654.3238)  time: 1.7935  data: 0.0025  max mem: 14694
# Epoch: [0]  [290/438]  eta: 0:04:38  lr: 0.000100  class_error: 28.85  loss: 5.4108 (6.0270)  loss_ce: 0.9938 (1.1788)  loss_bbox: 0.0734 (0.1056)  loss_giou: 0.0384 (0.0533)  loss_ce_0: 1.1163 (1.3255)  loss_bbox_0: 0.0901 (0.1238)  loss_giou_0: 0.0472 (0.0620)  loss_ce_1: 1.0051 (1.1966)  loss_bbox_1: 0.0808 (0.1084)  loss_giou_1: 0.0401 (0.0542)  loss_ce_enc: 1.5023 (1.4929)  loss_bbox_enc: 0.1865 (0.2110)  loss_giou_enc: 0.1062 (0.1150)  loss_ce_unscaled: 0.9938 (1.1788)  class_error_unscaled: 55.7692 (55.4785)  loss_bbox_unscaled: 0.0147 (0.0211)  loss_giou_unscaled: 0.0192 (0.0266)  cardinality_error_unscaled: 1760.5000 (2523.2955)  loss_ce_0_unscaled: 1.1163 (1.3255)  loss_bbox_0_unscaled: 0.0180 (0.0248)  loss_giou_0_unscaled: 0.0236 (0.0310)  cardinality_error_0_unscaled: 3575.2500 (3556.0765)  loss_ce_1_unscaled: 1.0051 (1.1966)  loss_bbox_1_unscaled: 0.0162 (0.0217)  loss_giou_1_unscaled: 0.0200 (0.0271)  cardinality_error_1_unscaled: 3872.7500 (3858.4699)  loss_ce_enc_unscaled: 1.5023 (1.4929)  loss_bbox_enc_unscaled: 0.0373 (0.0422)  loss_giou_enc_unscaled: 0.0531 (0.0575)  cardinality_error_enc_unscaled: 3702.2500 (3654.0034)  time: 1.7952  data: 0.0024  max mem: 14694
# Epoch: [0]  [300/438]  eta: 0:04:18  lr: 0.000100  class_error: 23.08  loss: 5.2525 (6.0098)  loss_ce: 0.9385 (1.1735)  loss_bbox: 0.0712 (0.1049)  loss_giou: 0.0372 (0.0529)  loss_ce_0: 1.1139 (1.3192)  loss_bbox_0: 0.1167 (0.1240)  loss_giou_0: 0.0624 (0.0621)  loss_ce_1: 0.9997 (1.1922)  loss_bbox_1: 0.0815 (0.1079)  loss_giou_1: 0.0401 (0.0539)  loss_ce_enc: 1.5003 (1.4929)  loss_bbox_enc: 0.1980 (0.2113)  loss_giou_enc: 0.1106 (0.1150)  loss_ce_unscaled: 0.9385 (1.1735)  class_error_unscaled: 36.5385 (55.3220)  loss_bbox_unscaled: 0.0142 (0.0210)  loss_giou_unscaled: 0.0186 (0.0265)  cardinality_error_unscaled: 1695.7500 (2492.8829)  loss_ce_0_unscaled: 1.1139 (1.3192)  loss_bbox_0_unscaled: 0.0233 (0.0248)  loss_giou_0_unscaled: 0.0312 (0.0311)  cardinality_error_0_unscaled: 3103.0000 (3540.2492)  loss_ce_1_unscaled: 0.9997 (1.1922)  loss_bbox_1_unscaled: 0.0163 (0.0216)  loss_giou_1_unscaled: 0.0200 (0.0270)  cardinality_error_1_unscaled: 3879.7500 (3859.1146)  loss_ce_enc_unscaled: 1.5003 (1.4929)  loss_bbox_enc_unscaled: 0.0396 (0.0423)  loss_giou_enc_unscaled: 0.0553 (0.0575)  cardinality_error_enc_unscaled: 3554.5000 (3648.6329)  time: 1.7852  data: 0.0030  max mem: 14694
# Epoch: [0]  [310/438]  eta: 0:03:59  lr: 0.000100  class_error: 13.46  loss: 5.3975 (5.9903)  loss_ce: 0.9385 (1.1653)  loss_bbox: 0.0800 (0.1060)  loss_giou: 0.0418 (0.0532)  loss_ce_0: 1.0887 (1.3112)  loss_bbox_0: 0.1221 (0.1250)  loss_giou_0: 0.0655 (0.0624)  loss_ce_1: 1.0242 (1.1852)  loss_bbox_1: 0.0881 (0.1087)  loss_giou_1: 0.0451 (0.0541)  loss_ce_enc: 1.4693 (1.4917)  loss_bbox_enc: 0.2264 (0.2121)  loss_giou_enc: 0.1174 (0.1154)  loss_ce_unscaled: 0.9385 (1.1653)  class_error_unscaled: 44.2308 (54.7242)  loss_bbox_unscaled: 0.0160 (0.0212)  loss_giou_unscaled: 0.0209 (0.0266)  cardinality_error_unscaled: 2013.0000 (2498.2090)  loss_ce_0_unscaled: 1.0887 (1.3112)  loss_bbox_0_unscaled: 0.0244 (0.0250)  loss_giou_0_unscaled: 0.0327 (0.0312)  cardinality_error_0_unscaled: 3535.5000 (3545.2838)  loss_ce_1_unscaled: 1.0242 (1.1852)  loss_bbox_1_unscaled: 0.0176 (0.0217)  loss_giou_1_unscaled: 0.0226 (0.0270)  cardinality_error_1_unscaled: 3881.2500 (3859.7862)  loss_ce_enc_unscaled: 1.4693 (1.4917)  loss_bbox_enc_unscaled: 0.0453 (0.0424)  loss_giou_enc_unscaled: 0.0587 (0.0577)  cardinality_error_enc_unscaled: 3520.2500 (3646.2010)  time: 1.7831  data: 0.0030  max mem: 14694
# Epoch: [0]  [320/438]  eta: 0:03:40  lr: 0.000100  class_error: 34.62  loss: 5.4711 (5.9731)  loss_ce: 1.0096 (1.1615)  loss_bbox: 0.0800 (0.1055)  loss_giou: 0.0422 (0.0530)  loss_ce_0: 1.0887 (1.3052)  loss_bbox_0: 0.1111 (0.1247)  loss_giou_0: 0.0576 (0.0623)  loss_ce_1: 1.0016 (1.1805)  loss_bbox_1: 0.0836 (0.1082)  loss_giou_1: 0.0445 (0.0539)  loss_ce_enc: 1.4431 (1.4899)  loss_bbox_enc: 0.2264 (0.2127)  loss_giou_enc: 0.1256 (0.1156)  loss_ce_unscaled: 1.0096 (1.1615)  class_error_unscaled: 44.2308 (54.6070)  loss_bbox_unscaled: 0.0160 (0.0211)  loss_giou_unscaled: 0.0211 (0.0265)  cardinality_error_unscaled: 2620.7500 (2500.8567)  loss_ce_0_unscaled: 1.0887 (1.3052)  loss_bbox_0_unscaled: 0.0222 (0.0249)  loss_giou_0_unscaled: 0.0288 (0.0312)  cardinality_error_0_unscaled: 3741.2500 (3552.3263)  loss_ce_1_unscaled: 1.0016 (1.1805)  loss_bbox_1_unscaled: 0.0167 (0.0216)  loss_giou_1_unscaled: 0.0222 (0.0269)  cardinality_error_1_unscaled: 3879.7500 (3860.4291)  loss_ce_enc_unscaled: 1.4431 (1.4899)  loss_bbox_enc_unscaled: 0.0453 (0.0425)  loss_giou_enc_unscaled: 0.0628 (0.0578)  cardinality_error_enc_unscaled: 3640.0000 (3646.7578)  time: 1.7809  data: 0.0024  max mem: 14694
# Epoch: [0]  [330/438]  eta: 0:03:21  lr: 0.000100  class_error: 67.31  loss: 5.5875 (5.9662)  loss_ce: 1.1007 (1.1590)  loss_bbox: 0.0881 (0.1062)  loss_giou: 0.0515 (0.0532)  loss_ce_0: 1.1316 (1.3004)  loss_bbox_0: 0.1146 (0.1255)  loss_giou_0: 0.0560 (0.0625)  loss_ce_1: 1.1291 (1.1784)  loss_bbox_1: 0.0900 (0.1089)  loss_giou_1: 0.0490 (0.0541)  loss_ce_enc: 1.4524 (1.4890)  loss_bbox_enc: 0.2288 (0.2134)  loss_giou_enc: 0.1208 (0.1158)  loss_ce_unscaled: 1.1007 (1.1590)  class_error_unscaled: 50.0000 (54.5782)  loss_bbox_unscaled: 0.0176 (0.0212)  loss_giou_unscaled: 0.0258 (0.0266)  cardinality_error_unscaled: 2286.2500 (2490.1586)  loss_ce_0_unscaled: 1.1316 (1.3004)  loss_bbox_0_unscaled: 0.0229 (0.0251)  loss_giou_0_unscaled: 0.0280 (0.0312)  cardinality_error_0_unscaled: 3712.5000 (3549.9547)  loss_ce_1_unscaled: 1.1291 (1.1784)  loss_bbox_1_unscaled: 0.0180 (0.0218)  loss_giou_1_unscaled: 0.0245 (0.0270)  cardinality_error_1_unscaled: 3877.5000 (3860.6956)  loss_ce_enc_unscaled: 1.4524 (1.4890)  loss_bbox_enc_unscaled: 0.0458 (0.0427)  loss_giou_enc_unscaled: 0.0604 (0.0579)  cardinality_error_enc_unscaled: 3628.2500 (3644.9282)  time: 1.7783  data: 0.0026  max mem: 14694
# Epoch: [0]  [340/438]  eta: 0:03:02  lr: 0.000100  class_error: 65.38  loss: 5.6749 (5.9508)  loss_ce: 1.1100 (1.1565)  loss_bbox: 0.0895 (0.1052)  loss_giou: 0.0471 (0.0527)  loss_ce_0: 1.1377 (1.2944)  loss_bbox_0: 0.1077 (0.1248)  loss_giou_0: 0.0495 (0.0622)  loss_ce_1: 1.1326 (1.1747)  loss_bbox_1: 0.0899 (0.1080)  loss_giou_1: 0.0477 (0.0537)  loss_ce_enc: 1.4580 (1.4881)  loss_bbox_enc: 0.2315 (0.2141)  loss_giou_enc: 0.1236 (0.1163)  loss_ce_unscaled: 1.1100 (1.1565)  class_error_unscaled: 53.8462 (54.6977)  loss_bbox_unscaled: 0.0179 (0.0210)  loss_giou_unscaled: 0.0235 (0.0264)  cardinality_error_unscaled: 2275.2500 (2489.3585)  loss_ce_0_unscaled: 1.1377 (1.2944)  loss_bbox_0_unscaled: 0.0215 (0.0250)  loss_giou_0_unscaled: 0.0247 (0.0311)  cardinality_error_0_unscaled: 3563.2500 (3549.0015)  loss_ce_1_unscaled: 1.1326 (1.1747)  loss_bbox_1_unscaled: 0.0180 (0.0216)  loss_giou_1_unscaled: 0.0238 (0.0268)  cardinality_error_1_unscaled: 3868.2500 (3860.8922)  loss_ce_enc_unscaled: 1.4580 (1.4881)  loss_bbox_enc_unscaled: 0.0463 (0.0428)  loss_giou_enc_unscaled: 0.0618 (0.0582)  cardinality_error_enc_unscaled: 3628.2500 (3645.7471)  time: 1.7809  data: 0.0026  max mem: 14694
# Epoch: [0]  [350/438]  eta: 0:02:43  lr: 0.000100  class_error: 1.92  loss: 5.5879 (5.9358)  loss_ce: 1.0964 (1.1537)  loss_bbox: 0.0670 (0.1043)  loss_giou: 0.0366 (0.0524)  loss_ce_0: 1.1205 (1.2892)  loss_bbox_0: 0.0928 (0.1241)  loss_giou_0: 0.0489 (0.0618)  loss_ce_1: 1.0533 (1.1717)  loss_bbox_1: 0.0706 (0.1071)  loss_giou_1: 0.0392 (0.0533)  loss_ce_enc: 1.4500 (1.4870)  loss_bbox_enc: 0.2407 (0.2148)  loss_giou_enc: 0.1297 (0.1165)  loss_ce_unscaled: 1.0964 (1.1537)  class_error_unscaled: 53.8462 (54.7173)  loss_bbox_unscaled: 0.0134 (0.0209)  loss_giou_unscaled: 0.0183 (0.0262)  cardinality_error_unscaled: 2448.5000 (2491.1546)  loss_ce_0_unscaled: 1.1205 (1.2892)  loss_bbox_0_unscaled: 0.0186 (0.0248)  loss_giou_0_unscaled: 0.0244 (0.0309)  cardinality_error_0_unscaled: 3476.7500 (3547.4167)  loss_ce_1_unscaled: 1.0533 (1.1717)  loss_bbox_1_unscaled: 0.0141 (0.0214)  loss_giou_1_unscaled: 0.0196 (0.0266)  cardinality_error_1_unscaled: 3870.7500 (3861.2315)  loss_ce_enc_unscaled: 1.4500 (1.4870)  loss_bbox_enc_unscaled: 0.0481 (0.0430)  loss_giou_enc_unscaled: 0.0649 (0.0583)  cardinality_error_enc_unscaled: 3666.0000 (3645.9665)  time: 1.7840  data: 0.0025  max mem: 14694
# ...
# Test:  [180/247]  eta: 0:00:10  class_error: 0.00  loss: 3.6272 (3.8028)  loss_ce: 0.5117 (0.6220)  loss_bbox: 0.0715 (0.0887)  loss_giou: 0.0400 (0.0468)  loss_ce_0: 0.5430 (0.6461)  loss_bbox_0: 0.1335 (0.1546)  loss_giou_0: 0.0698 (0.0770)  loss_ce_1: 0.4785 (0.6304)  loss_bbox_1: 0.1013 (0.1185)  loss_giou_1: 0.0527 (0.0605)  loss_ce_enc: 0.7656 (0.7423)  loss_bbox_enc: 0.4016 (0.4061)  loss_giou_enc: 0.2028 (0.2098)  loss_ce_unscaled: 0.5117 (0.6220)  class_error_unscaled: 25.0000 (22.2376)  loss_bbox_unscaled: 0.0143 (0.0177)  loss_giou_unscaled: 0.0200 (0.0234)  cardinality_error_unscaled: 298.5000 (293.2334)  loss_ce_0_unscaled: 0.5430 (0.6461)  loss_bbox_0_unscaled: 0.0267 (0.0309)  loss_giou_0_unscaled: 0.0349 (0.0385)  cardinality_error_0_unscaled: 299.0000 (293.1133)  loss_ce_1_unscaled: 0.4785 (0.6304)  loss_bbox_1_unscaled: 0.0203 (0.0237)  loss_giou_1_unscaled: 0.0263 (0.0303)  cardinality_error_1_unscaled: 298.7500 (295.5055)  loss_ce_enc_unscaled: 0.7656 (0.7423)  loss_bbox_enc_unscaled: 0.0803 (0.0812)  loss_giou_enc_unscaled: 0.1014 (0.1049)  cardinality_error_enc_unscaled: 293.5000 (286.3674)  time: 0.0913  data: 0.0034  max mem: 14694
# Test:  [190/247]  eta: 0:00:08  class_error: 50.00  loss: 3.2591 (3.7798)  loss_ce: 0.4766 (0.6142)  loss_bbox: 0.0754 (0.0897)  loss_giou: 0.0400 (0.0471)  loss_ce_0: 0.4844 (0.6388)  loss_bbox_0: 0.1374 (0.1553)  loss_giou_0: 0.0723 (0.0772)  loss_ce_1: 0.4688 (0.6228)  loss_bbox_1: 0.1047 (0.1194)  loss_giou_1: 0.0527 (0.0608)  loss_ce_enc: 0.6211 (0.7387)  loss_bbox_enc: 0.3713 (0.4063)  loss_giou_enc: 0.1996 (0.2097)  loss_ce_unscaled: 0.4766 (0.6142)  class_error_unscaled: 25.0000 (22.2513)  loss_bbox_unscaled: 0.0151 (0.0179)  loss_giou_unscaled: 0.0200 (0.0236)  cardinality_error_unscaled: 298.5000 (292.9804)  loss_ce_0_unscaled: 0.4844 (0.6388)  loss_bbox_0_unscaled: 0.0275 (0.0311)  loss_giou_0_unscaled: 0.0362 (0.0386)  cardinality_error_0_unscaled: 298.5000 (292.9045)  loss_ce_1_unscaled: 0.4688 (0.6228)  loss_bbox_1_unscaled: 0.0209 (0.0239)  loss_giou_1_unscaled: 0.0263 (0.0304)  cardinality_error_1_unscaled: 298.7500 (295.3390)  loss_ce_enc_unscaled: 0.6211 (0.7387)  loss_bbox_enc_unscaled: 0.0743 (0.0813)  loss_giou_enc_unscaled: 0.0998 (0.1048)  cardinality_error_enc_unscaled: 290.5000 (285.9817)  time: 0.0895  data: 0.0034  max mem: 14694
# Test:  [200/247]  eta: 0:00:07  class_error: 0.00  loss: 3.1545 (3.7649)  loss_ce: 0.4375 (0.6100)  loss_bbox: 0.0742 (0.0891)  loss_giou: 0.0376 (0.0470)  loss_ce_0: 0.4844 (0.6370)  loss_bbox_0: 0.1339 (0.1545)  loss_giou_0: 0.0687 (0.0771)  loss_ce_1: 0.4512 (0.6193)  loss_bbox_1: 0.1037 (0.1188)  loss_giou_1: 0.0518 (0.0607)  loss_ce_enc: 0.6094 (0.7376)  loss_bbox_enc: 0.3685 (0.4046)  loss_giou_enc: 0.1926 (0.2090)  loss_ce_unscaled: 0.4375 (0.6100)  class_error_unscaled: 25.0000 (21.8905)  loss_bbox_unscaled: 0.0148 (0.0178)  loss_giou_unscaled: 0.0188 (0.0235)  cardinality_error_unscaled: 298.2500 (292.9303)  loss_ce_0_unscaled: 0.4844 (0.6370)  loss_bbox_0_unscaled: 0.0268 (0.0309)  loss_giou_0_unscaled: 0.0344 (0.0386)  cardinality_error_0_unscaled: 298.5000 (292.8507)  loss_ce_1_unscaled: 0.4512 (0.6193)  loss_bbox_1_unscaled: 0.0207 (0.0238)  loss_giou_1_unscaled: 0.0259 (0.0304)  cardinality_error_1_unscaled: 298.2500 (295.2910)  loss_ce_enc_unscaled: 0.6094 (0.7376)  loss_bbox_enc_unscaled: 0.0737 (0.0809)  loss_giou_enc_unscaled: 0.0963 (0.1045)  cardinality_error_enc_unscaled: 292.7500 (286.0149)  time: 0.1134  data: 0.0034  max mem: 14694
# Test:  [210/247]  eta: 0:00:05  class_error: 25.00  loss: 3.1389 (3.7308)  loss_ce: 0.3984 (0.6009)  loss_bbox: 0.0718 (0.0889)  loss_giou: 0.0414 (0.0471)  loss_ce_0: 0.4707 (0.6284)  loss_bbox_0: 0.1321 (0.1537)  loss_giou_0: 0.0705 (0.0770)  loss_ce_1: 0.4297 (0.6105)  loss_bbox_1: 0.1002 (0.1185)  loss_giou_1: 0.0527 (0.0608)  loss_ce_enc: 0.6133 (0.7326)  loss_bbox_enc: 0.3701 (0.4033)  loss_giou_enc: 0.1998 (0.2092)  loss_ce_unscaled: 0.3984 (0.6009)  class_error_unscaled: 0.0000 (21.5640)  loss_bbox_unscaled: 0.0144 (0.0178)  loss_giou_unscaled: 0.0207 (0.0235)  cardinality_error_unscaled: 298.7500 (292.9645)  loss_ce_0_unscaled: 0.4707 (0.6284)  loss_bbox_0_unscaled: 0.0264 (0.0307)  loss_giou_0_unscaled: 0.0352 (0.0385)  cardinality_error_0_unscaled: 299.0000 (292.8306)  loss_ce_1_unscaled: 0.4297 (0.6105)  loss_bbox_1_unscaled: 0.0200 (0.0237)  loss_giou_1_unscaled: 0.0264 (0.0304)  cardinality_error_1_unscaled: 298.7500 (295.3258)  loss_ce_enc_unscaled: 0.6133 (0.7326)  loss_bbox_enc_unscaled: 0.0740 (0.0807)  loss_giou_enc_unscaled: 0.0999 (0.1046)  cardinality_error_enc_unscaled: 295.0000 (285.7358)  time: 0.1154  data: 0.0035  max mem: 14694
# Test:  [220/247]  eta: 0:00:04  class_error: 0.00  loss: 3.2640 (3.7529)  loss_ce: 0.4688 (0.6094)  loss_bbox: 0.0718 (0.0880)  loss_giou: 0.0414 (0.0467)  loss_ce_0: 0.4941 (0.6358)  loss_bbox_0: 0.1289 (0.1526)  loss_giou_0: 0.0705 (0.0767)  loss_ce_1: 0.4883 (0.6187)  loss_bbox_1: 0.0969 (0.1174)  loss_giou_1: 0.0523 (0.0603)  loss_ce_enc: 0.6758 (0.7366)  loss_bbox_enc: 0.3719 (0.4019)  loss_giou_enc: 0.2088 (0.2088)  loss_ce_unscaled: 0.4688 (0.6094)  class_error_unscaled: 25.0000 (22.0588)  loss_bbox_unscaled: 0.0144 (0.0176)  loss_giou_unscaled: 0.0207 (0.0234)  cardinality_error_unscaled: 298.7500 (293.2285)  loss_ce_0_unscaled: 0.4941 (0.6358)  loss_bbox_0_unscaled: 0.0258 (0.0305)  loss_giou_0_unscaled: 0.0352 (0.0383)  cardinality_error_0_unscaled: 299.0000 (293.1086)  loss_ce_1_unscaled: 0.4883 (0.6187)  loss_bbox_1_unscaled: 0.0194 (0.0235)  loss_giou_1_unscaled: 0.0262 (0.0302)  cardinality_error_1_unscaled: 299.0000 (295.4796)  loss_ce_enc_unscaled: 0.6758 (0.7366)  loss_bbox_enc_unscaled: 0.0744 (0.0804)  loss_giou_enc_unscaled: 0.1044 (0.1044)  cardinality_error_enc_unscaled: 295.5000 (286.1618)  time: 0.0911  data: 0.0036  max mem: 14694
# Test:  [230/247]  eta: 0:00:02  class_error: 25.00  loss: 3.3969 (3.7451)  loss_ce: 0.6211 (0.6082)  loss_bbox: 0.0618 (0.0870)  loss_giou: 0.0341 (0.0463)  loss_ce_0: 0.5938 (0.6345)  loss_bbox_0: 0.1196 (0.1511)  loss_giou_0: 0.0622 (0.0760)  loss_ce_1: 0.6133 (0.6178)  loss_bbox_1: 0.0872 (0.1160)  loss_giou_1: 0.0438 (0.0598)  loss_ce_enc: 0.7461 (0.7375)  loss_bbox_enc: 0.3785 (0.4015)  loss_giou_enc: 0.2151 (0.2094)  loss_ce_unscaled: 0.6211 (0.6082)  class_error_unscaled: 25.0000 (22.1861)  loss_bbox_unscaled: 0.0124 (0.0174)  loss_giou_unscaled: 0.0171 (0.0232)  cardinality_error_unscaled: 298.7500 (293.3420)  loss_ce_0_unscaled: 0.5938 (0.6345)  loss_bbox_0_unscaled: 0.0239 (0.0302)  loss_giou_0_unscaled: 0.0311 (0.0380)  cardinality_error_0_unscaled: 299.0000 (293.2045)  loss_ce_1_unscaled: 0.6133 (0.6178)  loss_bbox_1_unscaled: 0.0174 (0.0232)  loss_giou_1_unscaled: 0.0219 (0.0299)  cardinality_error_1_unscaled: 298.7500 (295.5833)  loss_ce_enc_unscaled: 0.7461 (0.7375)  loss_bbox_enc_unscaled: 0.0757 (0.0803)  loss_giou_enc_unscaled: 0.1076 (0.1047)  cardinality_error_enc_unscaled: 295.2500 (286.1883)  time: 0.0891  data: 0.0034  max mem: 14694
# Test:  [240/247]  eta: 0:00:01  class_error: 25.00  loss: 3.5549 (3.7677)  loss_ce: 0.6055 (0.6145)  loss_bbox: 0.0627 (0.0876)  loss_giou: 0.0351 (0.0467)  loss_ce_0: 0.5938 (0.6400)  loss_bbox_0: 0.1272 (0.1511)  loss_giou_0: 0.0677 (0.0762)  loss_ce_1: 0.6133 (0.6244)  loss_bbox_1: 0.0875 (0.1164)  loss_giou_1: 0.0453 (0.0600)  loss_ce_enc: 0.7773 (0.7415)  loss_bbox_enc: 0.3763 (0.4003)  loss_giou_enc: 0.2074 (0.2090)  loss_ce_unscaled: 0.6055 (0.6145)  class_error_unscaled: 25.0000 (22.4066)  loss_bbox_unscaled: 0.0125 (0.0175)  loss_giou_unscaled: 0.0175 (0.0233)  cardinality_error_unscaled: 298.5000 (293.5176)  loss_ce_0_unscaled: 0.5938 (0.6400)  loss_bbox_0_unscaled: 0.0254 (0.0302)  loss_giou_0_unscaled: 0.0338 (0.0381)  cardinality_error_0_unscaled: 299.0000 (293.3797)  loss_ce_1_unscaled: 0.6133 (0.6244)  loss_bbox_1_unscaled: 0.0175 (0.0233)  loss_giou_1_unscaled: 0.0226 (0.0300)  cardinality_error_1_unscaled: 298.7500 (295.6878)  loss_ce_enc_unscaled: 0.7773 (0.7415)  loss_bbox_enc_unscaled: 0.0753 (0.0801)  loss_giou_enc_unscaled: 0.1037 (0.1045)  cardinality_error_enc_unscaled: 294.0000 (286.3828)  time: 0.0888  data: 0.0035  max mem: 14694
# Test:  [246/247]  eta: 0:00:00  class_error: 0.00  loss: 3.5476 (3.7571)  loss_ce: 0.5859 (0.6126)  loss_bbox: 0.0633 (0.0875)  loss_giou: 0.0351 (0.0466)  loss_ce_0: 0.5938 (0.6373)  loss_bbox_0: 0.1193 (0.1506)  loss_giou_0: 0.0622 (0.0762)  loss_ce_1: 0.6094 (0.6220)  loss_bbox_1: 0.0851 (0.1161)  loss_giou_1: 0.0453 (0.0599)  loss_ce_enc: 0.7031 (0.7395)  loss_bbox_enc: 0.3713 (0.3996)  loss_giou_enc: 0.1870 (0.2092)  loss_ce_unscaled: 0.5859 (0.6126)  class_error_unscaled: 25.0000 (22.2672)  loss_bbox_unscaled: 0.0127 (0.0175)  loss_giou_unscaled: 0.0175 (0.0233)  cardinality_error_unscaled: 298.3333 (293.5793)  loss_ce_0_unscaled: 0.5938 (0.6373)  loss_bbox_0_unscaled: 0.0239 (0.0301)  loss_giou_0_unscaled: 0.0311 (0.0381)  cardinality_error_0_unscaled: 298.7500 (293.4065)  loss_ce_1_unscaled: 0.6094 (0.6220)  loss_bbox_1_unscaled: 0.0170 (0.0232)  loss_giou_1_unscaled: 0.0226 (0.0300)  cardinality_error_1_unscaled: 298.5000 (295.7217)  loss_ce_enc_unscaled: 0.7031 (0.7395)  loss_bbox_enc_unscaled: 0.0743 (0.0799)  loss_giou_enc_unscaled: 0.0935 (0.1046)  cardinality_error_enc_unscaled: 293.2500 (286.4295)  time: 0.0886  data: 0.0037  max mem: 14694
# Test: Total time: 0:00:36 (0.1468 s / it)
# Averaged stats: class_error: 0.00  loss: 3.5476 (3.7571)  loss_ce: 0.5859 (0.6126)  loss_bbox: 0.0633 (0.0875)  loss_giou: 0.0351 (0.0466)  loss_ce_0: 0.5938 (0.6373)  loss_bbox_0: 0.1193 (0.1506)  loss_giou_0: 0.0622 (0.0762)  loss_ce_1: 0.6094 (0.6220)  loss_bbox_1: 0.0851 (0.1161)  loss_giou_1: 0.0453 (0.0599)  loss_ce_enc: 0.7031 (0.7395)  loss_bbox_enc: 0.3713 (0.3996)  loss_giou_enc: 0.1870 (0.2092)  loss_ce_unscaled: 0.5859 (0.6126)  class_error_unscaled: 25.0000 (22.2672)  loss_bbox_unscaled: 0.0127 (0.0175)  loss_giou_unscaled: 0.0175 (0.0233)  cardinality_error_unscaled: 298.3333 (293.5793)  loss_ce_0_unscaled: 0.5938 (0.6373)  loss_bbox_0_unscaled: 0.0239 (0.0301)  loss_giou_0_unscaled: 0.0311 (0.0381)  cardinality_error_0_unscaled: 298.7500 (293.4065)  loss_ce_1_unscaled: 0.6094 (0.6220)  loss_bbox_1_unscaled: 0.0170 (0.0232)  loss_giou_1_unscaled: 0.0226 (0.0300)  cardinality_error_1_unscaled: 298.5000 (295.7217)  loss_ce_enc_unscaled: 0.7031 (0.7395)  loss_bbox_enc_unscaled: 0.0743 (0.0799)  loss_giou_enc_unscaled: 0.0935 (0.1046)  cardinality_error_enc_unscaled: 293.2500 (286.4295)
# Accumulating evaluation results...
# DONE (t=1.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.821
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.990
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.993
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.994
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.994
# Test results: {'class_error': 22.267206477732792, 'loss': 3.757141788478805, 'loss_ce': 0.6125834229504049, 'loss_bbox': 0.08745644893120175, 'loss_giou': 0.04662990530854777, 'loss_ce_0': 0.6372880819838057, 'loss_bbox_0': 0.1506240002599805, 'loss_giou_0': 0.07623038332351306, 'loss_ce_1': 0.6220248450151822, 'loss_bbox_1': 0.11605353010931478, 'loss_giou_1': 0.059927474269982774, 'loss_ce_enc': 0.7394515435222672, 'loss_bbox_enc': 0.3996395077782604, 'loss_giou_enc': 0.2092326413161359, 'loss_ce_unscaled': 0.6125834229504049, 'class_error_unscaled': 22.267206477732792, 'loss_bbox_unscaled': 0.017491289802830712, 'loss_giou_unscaled': 0.023314952654273885, 'cardinality_error_unscaled': 293.5792847915217, 'loss_ce_0_unscaled': 0.6372880819838057, 'loss_bbox_0_unscaled': 0.030124800061045388, 'loss_giou_0_unscaled': 0.03811519166175653, 'cardinality_error_0_unscaled': 293.4065452915454, 'loss_ce_1_unscaled': 0.6220248450151822, 'loss_bbox_1_unscaled': 0.023210706008289023, 'loss_giou_1_unscaled': 0.029963737134991387, 'cardinality_error_1_unscaled': 295.72165991902835, 'loss_ce_enc_unscaled': 0.7394515435222672, 'loss_bbox_enc_unscaled': 0.07992790141689633, 'loss_giou_enc_unscaled': 0.10461632065806795, 'cardinality_error_enc_unscaled': 286.4294872206715, 'results_json': {'class_map': [{'class': 'Convertible', 'map@50:95': 0.9348225209318047, 'map@50': 0.9396520947356257, 'precision': 0.9384615384615385, 'recall': 0.75}, {'class': 'Crossover', 'map@50:95': 0.8726237297900705, 'map@50': 0.8821739131216608, 'precision': 0.8591549295774648, 'recall': 0.75}, {'class': 'Fastback', 'map@50:95': 0.6857319857819839, 'map@50': 0.6888163343608928, 'precision': 0.5384615384615384, 'recall': 0.75}, {'class': 'Hardtop Convertible', 'map@50:95': 0.7833666745103022, 'map@50': 0.7942715410113649, 'precision': 0.7682926829268293, 'recall': 0.75}, {'class': 'Hatchback', 'map@50:95': 0.605625335592686, 'map@50': 0.6102378690753147, 'precision': 0.3885350318471338, 'recall': 0.75}, {'class': 'MPV', 'map@50:95': 0.8951965756873764, 'map@50': 0.8958726662421856, 'precision': 0.9041095890410958, 'recall': 0.75}, {'class': 'Minibus', 'map@50:95': 0.9630979794267008, 'map@50': 0.9833884289568359, 'precision': 1.0, 'recall': 0.75}, {'class': 'Pickup Truck', 'map@50:95': 0.971960215131105, 'map@50': 0.9793594737732195, 'precision': 0.9876543209876543, 'recall': 0.75}, {'class': 'SUV', 'map@50:95': 0.8268266593085948, 'map@50': 0.8353908989160844, 'precision': 0.7721518987341772, 'recall': 0.75}, {'class': 'Sedan', 'map@50:95': 0.6709255783421624, 'map@50': 0.6741041292470081, 'precision': 0.5377358490566038, 'recall': 0.75}, {'class': 'Sports', 'map@50:95': 0.7069595041847255, 'map@50': 0.721147919735594, 'precision': 0.5478260869565217, 'recall': 0.75}, {'class': 'Wagon', 'map@50:95': 0.9383230528119868, 'map@50': 0.9416685285521277, 'precision': 0.9692307692307692, 'recall': 0.75}, {'class': 'all', 'map@50:95': 0.8212883176249582, 'map@50': 0.8288403164773261, 'precision': 0.7676345196067773, 'recall': 0.75}], 'map': 0.8288403164773261, 'precision': 0.7676345196067773, 'recall': 0.75}, 'coco_eval_bbox': [0.8212883176249582, 0.8288403164773261, 0.8264688790906352, -1.0, -1.0, 0.8214145122568185, 0.9899920134863653, 0.9931791064952455, 0.9938558433762507, -1.0, -1.0, 0.9938558433762507]}
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
ls -la output
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 20BB-771E
#
#  Directory of c:\Users\user\Documents\Vehicle-Detection-at-R-R-\notebooks
#
#
#  Directory of c:\Users\user\Documents\Vehicle-Detection-at-R-R-\notebooks\output
#
# 04/11/2025  01:22 AM    <DIR>          .
# 04/11/2025  12:48 AM    <DIR>          ..
# 04/11/2025  01:19 AM       483,833,933 checkpoint.pth
# 04/11/2025  01:21 AM       362,914,282 checkpoint_best_ema.pth
# 04/11/2025  12:57 AM       362,921,798 checkpoint_best_regular.pth
# 04/11/2025  01:21 AM       120,941,407 checkpoint_best_total.pth
# 04/11/2025  12:50 AM    <DIR>          eval
# 04/11/2025  01:21 AM            39,060 log.txt
# 04/11/2025  01:22 AM           160,393 metrics_plot.png
# 04/11/2025  01:22 AM             3,575 results.json
#                7 File(s)  1,330,814,448 bytes
#                3 Dir(s)  342,621,671,424 bytes free
# File Not Found

# %% [markdown]
# ## Deploy a Trained RF-DETR Model
#
# Deploying to Roboflow allows you to create multi-step computer vision applications that run both in the cloud and your own hardware. Please wait a moment while Roboflow indexes your model.

# %%
# model.deploy_to_roboflow(
#   workspace="roboflow-jvuqo",
#   project_id="basketball-player-detection-2",
#   version=13,
#   api_key=os.environ["ROBOFLOW_API_KEY"]
# )
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/13
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/model/13

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 169.93 MB | Reserved: 6450.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 169.93 MB | Reserved: 420.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRBase(pretrain_weights="output/checkpoint_best_total.pth")
model.optimize_for_inference()
# Out:
# num_classes mismatch: pretrain weights has 12 classes, but your model has 90 classes
# reinitializing detection head with 12 classes
# Loading pretrain weights
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 987/987 [00:24<00:00, 40.36it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.821
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.829
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.827
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]                 = -1.000
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]                 = 0.822

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[7]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
# !pip install -q inference-gpu==0.51.7

# %%
from inference import get_model

MODEL_ID = "basketball-player-detection-2/13"
model_rf = get_model(model_id=MODEL_ID, api_key = userdata.get("ROBOFLOW_API_KEY"))

# %%
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

result = model_rf.infer(image, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       4 path, image, annotations = ds[0]
#       5 image = Image.open(path)
# ----> 7 result = model_rf.infer(image, confidence=0.3)[0]
#       8 detections = sv.Detections.from_inference(result)
#      10 text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
#
# NameError: name 'model_rf' is not defined

# %% [markdown]
# <div align="center">
#   <p>
#     Looking for more tutorials or have questions?
#     Check out our <a href="https://github.com/roboflow/notebooks">GitHub repo</a> for more notebooks,
#     or visit our <a href="https://discord.gg/GbfgXGJ8Bk">discord</a>.
#   </p>
#
#   <p>
#     <strong>If you found this helpful, please consider giving us a ⭐
#     <a href="https://github.com/roboflow/notebooks">on GitHub</a>!</strong>
#   </p>
#
# </div>
